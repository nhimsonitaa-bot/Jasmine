# %% [markdown]
# <a href="https://colab.research.google.com/github/nhimsonitaa-bot/Jasmine/blob/main/testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile my_module.py

def add(a, b):
    return a + b

def multiply(a, b):
    return a * b

greeting = "안녕하세요! 사용자 정의 모듈입니다."
# Out:
# Overwriting my_module.py

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# files      module    <module 'google.colab.fil<...>s/google/colab/files.py'>

# %%
import my_module as mmo

# 모듈 내부 함수 호출
print(my_module.add(10, 20))
print(my_module.multiply(5, 4))

# 모듈 내부 변수 집근
print(my_module.greeting)
# Out:
# 30
# 20
# 안녕하세요! 사용자 정의 모듈입니다.

# %%
import pandas as pd
pd

# %%
a = [1,2,3,4,5]

# %%
# %whos
# Out:
# Variable    Type      Data/Info
# -------------------------------
# files       module    <module 'google.colab.fil<...>s/google/colab/files.py'>
# mm0         module    <module 'my_module' from '/content/my_module.py'>
# mmo         module    <module 'my_module' from '/content/my_module.py'>
# my_module   module    <module 'my_module' from '/content/my_module.py'>
