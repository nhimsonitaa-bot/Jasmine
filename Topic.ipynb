# %% [markdown]
# <a href="https://colab.research.google.com/github/nhimsonitaa-bot/Jasmine/blob/main/Topic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Management Application

## 프로젝트 소개

학생 정보를 효율적으로 관리할 수 있는 간단한 애플리케이션입니다.
학생의 기본 정보를 등록하고 조회할 수 있도록 구성하였습니다.

## 주요 기능

- 학생 정보 등록
- 학생 정보 조회
- 학생 정보 수정 및 삭제
- 간단하고 편리한 사용자 인터페이스 제공

## 사용 기술

- HTML
- CSS
- JavaScript

## 실행 방법

프로젝트 파일을 다운로드한 후 HTML 파일을 실행합니다.
웹 브라우저에서 애플리케이션을 확인할 수 있습니다.
